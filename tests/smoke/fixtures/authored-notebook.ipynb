# %% [markdown]
# # Authored Notebook Concept

# %% [markdown]
# ## Bayesian Warmup
#
# Inline math like $x$ stays inline.
#
# $$
# x^2 + y^2
# $$

# %% [markdown]
# ![alt](./assets/paste-20260101-000000.png)

# %%
def show_example():
    doc = """
    ```python
    print('inside fence')
    ```
    """
    return doc

# %%
result = 2 + 2
print(result)
# Out:
# rendered notebook output

# %% [markdown]
# ## Second Section
#
# A later section should trigger a separator in flattened output.
